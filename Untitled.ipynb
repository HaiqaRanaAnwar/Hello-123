# %%
print(haiqa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6877fbb719c3> in <module>
# ----> 1 print(haiqa)
#
# NameError: name 'haiqa' is not defined

# %%
print(1)
# Out:
# 1

# %%
print('haiqa')
# Out:
# haiqa

# %%
print('Twinkle,Twinkle,Little Star, ') 
print('\t How I wonder, What are you!')
print(' \t \t Up above the world so high,')
print(' \t \t Like a diamond in the sky,')
print('Twinkle,Twinkle,Little star, ')
print('\t How I wonder, What are you!')
# Out:
# Twinkle,Twinkle,Little Star,
# 	 How I wonder, What are you!
#  	 	 Up above the world so high,
#  	 	 Like a diamond in the sky,
# Twinkle,Twinkle,Little star,
# 	 How I wonder, What are you!

# %%
import sys
print(sys.version)
# Out:
# 3.7.8 | packaged by conda-forge | (default, Nov 17 2020, 23:42:15)
# [GCC 7.5.0]

# %%
from datetime import date 
today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2021-12-31

# %%
r = float(input("Enter radius of circle: "))
a = 3.14159 * r * r
print("Area of circle =", a)
# Out:
# Enter radius of circle:  455.2
# Area of circle = 650959.5647935999

# %%
fname = input("Input your First Name : ")

lname = input("Input your Last Name : ")

print ("Hello " + lname + " " + fname)
# Out:
# Input your First Name :  Haiqa
# Input your Last Name :  Rana Anwar
# Hello Rana Anwar  Haiqa

# %%
sum1 = int(input("Write 1st number:"))
sum2 = int(input("Write 2nd number:"))
sum = sum1+sum2
print(sum)
# Out:
# Write 1st number: 5
# Write 2nd number: 5
# 10
